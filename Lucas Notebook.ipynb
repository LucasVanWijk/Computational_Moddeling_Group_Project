# %% [markdown]
# I will be making a couple of graps to display the data set

# %%
import matplotlib
import pandas as pd
redwines = pd.read_csv("redwine.csv", delimiter=";", encoding='iso-8859-1')

# %%
boxplot = redwines.boxplot('price')

# %%
boxplot = redwines.boxplot('points')

# %%
boxplot = redwines.boxplot('residual sugar')

# %%
boxplot = redwines.boxplot('pH')
