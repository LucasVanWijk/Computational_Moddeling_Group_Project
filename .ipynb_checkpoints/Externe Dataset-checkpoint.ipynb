# %%
# importeer nodige libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# lees de externe dataset in
temperatures = pd.read_csv("weatherdata_lisbon.csv", delimiter=";", encoding='iso-8859-1')
temperatures.head()
# Out:
#    STN---  YEARMODA  TEMP  DEWP VISIB  Unnamed: 5 WDSP  Unnamed: 7 MXSPD  \
# 0   85360  19900101  55,1  50,5   6,3          24  5,8          24    13
# 1   85360  19900102  50,2  47,7     5          24  5,8          24    21
# 2   85360  19900103  49,5  46,6   6,6          24  4,8          24   9,9
# 3   85360  19900104  52,1  50,7     5          24  1,7          24     6
# 4   85360  19900105  54,2    54   1,2          22    1          22   4,1
#
#     GUST    MAX    MIN   PRCP   SNDP  FRSHTT
# 0  999,9  59.0*  44.6*  99,99  999,9   10000
# 1  999,9  59.0*  42.8*  99,99  999,9  110010
# 2     20  55.4*  44.6*  99,99  999,9   10000
# 3  999,9  57.2*  46.4*  99,99  999,9   10000
# 4  999,9  55.4*  53.6*  99,99  999,9  110000

# %%
temperatures.drop(['STN---','Unnamed: 5','Unnamed: 7','GUST','PRCP','SNDP','VISIB'], axis=1,inplace=True)
# FRSHTT = Frost, Rain, Snow, Hail, Thunder, Thornado
temperatures.rename(columns={'YEARMODA': 'Year', 'TEMP': 'Temperature','DEWP':'Dewpoint Temperature','MAX':'Max Temperature','MIN':'Min Temperature','WDSP':'Windspeed','MXSPD':'Max Windspeed'},inplace=True)
temperatures['Max Temperature'] = (temperatures['Max Temperature'].str.replace(',','.').str.rstrip("*").astype(float) - 32) / 1.8
temperatures['Min Temperature'] = (temperatures['Min Temperature'].str.replace(',','.').str.rstrip("*").astype(float) - 32) / 1.8
temperatures['Temperature'] = round((temperatures['Temperature'].str.replace(',','.').astype(float) - 32) / 1.8, 2)
temperatures['Windspeed'] = temperatures['Windspeed'].str.replace(',','.').astype(float)
temperatures['Max Windspeed'] = temperatures['Max Windspeed'].str.replace(',','.').astype(float)
temperatures['Dewpoint Temperature'] = round((temperatures['Dewpoint Temperature'].str.replace(',','.').astype(float) - 32) / 1.8, 2)
temperatures['Year']= pd.to_datetime(temperatures['Year'].astype(str), format='%Y-%m-%d')
temperatures['FRSHTT'] = temperatures['FRSHTT'].apply(lambda x: '{0:0>6}'.format(x))
# make the new columns using string indexing
temperatures['Frost'] = temperatures['FRSHTT'].str[0].astype(float)
temperatures['Rain'] = temperatures['FRSHTT'].str[1].astype(float)
temperatures['Snow'] = temperatures['FRSHTT'].str[2].astype(float)
temperatures['Hail'] = temperatures['FRSHTT'].str[3].astype(float)
temperatures['Thunder'] = temperatures['FRSHTT'].str[4].astype(float)
temperatures['Thornado'] = temperatures['FRSHTT'].str[5].astype(float)
temperatures.drop('FRSHTT',axis=1,inplace=True)
temperatures['Count'] = 1
peryear = temperatures.groupby(temperatures['Year'].map(lambda x: x.year)).sum()
peryear = peryear[['Temperature','Dewpoint Temperature','Windspeed','Max Windspeed','Max Temperature','Min Temperature','Frost','Rain','Snow','Hail','Thunder','Thornado']].div(peryear['Count'], axis=0)
#peryear = peryear[['Frost','Rain','Snow','Hail','Thunder','Thornado'] * 100].round(4)
peryear
# Out:
#       Temperature  Dewpoint Temperature  Windspeed  Max Windspeed  \
# Year
# 1990    17.164380            266.894063   6.589625      13.044092
# 1991    16.773806            747.164000   6.931111      13.949722
# 1992    16.802623            417.788934  10.007923      16.910929
# 1993    16.383626             26.702582   6.839560      12.929945
# 1994    16.969342             42.455890   7.199178      13.518904
# 1995    17.995205             42.179726   6.978630      13.566849
# 1996    17.137432             12.306148   7.124863      13.982514
# 1997    18.222473             13.332280   7.435440      13.345055
# 1998    17.581022             27.560608   7.892541      13.551657
# 1999    17.373196             27.872342   8.211846      13.877410
# 2000    16.829071             11.735929   8.412568      14.268579
# 2001    16.786384             12.071890   8.637534      14.192055
# 2002    16.877370             12.720712   8.455616      14.497260
# ...
